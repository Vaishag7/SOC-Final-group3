# %% [markdown]
# <a href="https://colab.research.google.com/github/Vaishag7/SOC-Final-group3/blob/main/GAN_Implementation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense, LeakyReLU, Dropout, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import SGD, Adam

# %%
mnist = tf.keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()
# Scale the inputs in range of (-1, +1) for better training
x_train, x_test = x_train / 255.0 * 2 - 1, x_test / 255.0 * 2 - 1
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step

# %%
for i in range(49):
  plt.subplot(7, 7, i+1)
  plt.axis("off")
  #plot raw pixel data
  plt.imshow(x_train[i])
plt.show()

# %%
N, H, W = x_train.shape  #number, height, width
D = H * W   #dimension (28, 28)
x_train = x_train.reshape(-1, D) 
x_test = x_test.reshape(-1, D)

# %%
# Defining Generator Model
latent_dim = 100
def build_generator(latent_dim):
  i = Input(shape=(latent_dim,))
  x = Dense(256, activation=LeakyReLU(alpha=0.2))(i)
  x = BatchNormalization(momentum=0.7)(x)
  x = Dense(512, activation=LeakyReLU(alpha=0.2))(x)
  x = BatchNormalization(momentum=0.7)(x)
  x = Dense(1024, activation=LeakyReLU(alpha=0.2))(x)
  x = BatchNormalization(momentum=0.7)(x)
  x = Dense(D, activation='tanh')(x)  #because Image pixel is between -1 to 1.
  model = Model(i, x)  #i is input x is output layer
  return model

# %%
def build_discriminator(img_size):
  i = Input(shape=(img_size,))
  x = Dense(512, activation=LeakyReLU(alpha=0.2))(i)
  x = Dense(256, activation=LeakyReLU(alpha=0.2))(x)
  x = Dense(1, activation='sigmoid')(x)
  model = Model(i, x)
  return model

# %%
# Build and compile the discriminator
discriminator = build_discriminator(D)
discriminator.compile ( loss='binary_crossentropy', optimizer=Adam(0.0002, 0.5), metrics=['accuracy'])
# Build and compile the combined model
generator = build_generator(latent_dim)

# %%
## Create an input to represent noise sample from latent space
z = Input(shape=(latent_dim,))
## Pass noise through a generator to get an Image
img = generator(z)
discriminator.trainable = False
fake_pred = discriminator(img)

# %%
combined_model_gen = Model(z, fake_pred)  #first is noise and 2nd is fake prediction
# Compile the combined model
combined_model_gen.compile(loss='binary_crossentropy', optimizer=Adam(0.0002, 0.5))

# %%
batch_size = 32
epochs = 12000
sample_period = 200
ones = np.ones(batch_size)
zeros = np.zeros(batch_size)
#store generator and discriminator loss in each step or each epoch
d_losses = []
g_losses = []
#create a file in which generator will create and save images
if not os.path.exists('gan_images'):
  os.makedirs('gan_images')

# %%
def sample_images(epoch):
  rows, cols = 5, 5
  noise = np.random.randn(rows * cols, latent_dim)
  imgs = generator.predict(noise)
  # Rescale images 0 - 1
  imgs = 0.5 * imgs + 0.5
  fig, axs = plt.subplots(rows, cols)  #fig to plot img and axis to store
  idx = 0
  for i in range(rows):  #5*5 loop means on page 25 imgs will be there
    for j in range(cols):
      axs[i,j].imshow(imgs[idx].reshape(H, W), cmap='gray')
      axs[i,j].axis('off')
      idx += 1
  fig.savefig("gan_images/%d.png" % epoch)
  plt.close()

# %%
#FIRST we will train Discriminator(with real imgs and fake imgs)
# Main training loop
for epoch in range(epochs):
  ###########################
  ### Train discriminator ###
  ###########################
  # Select a random batch of images
  idx = np.random.randint(0, x_train.shape[0], batch_size)
  real_imgs = x_train[idx]  #MNIST dataset
  # Generate fake images
  noise = np.random.randn(batch_size, latent_dim)  #generator to generate fake imgs
  fake_imgs = generator.predict(noise)
  # Train the discriminator
  # both loss and accuracy are returned
  d_loss_real, d_acc_real = discriminator.train_on_batch(real_imgs, ones)  #belong to positive class(real imgs)
  d_loss_fake, d_acc_fake = discriminator.train_on_batch(fake_imgs, zeros)  #fake imgs
  d_loss = 0.5 * (d_loss_real + d_loss_fake)
  d_acc  = 0.5 * (d_acc_real + d_acc_fake)
  #######################
  ### Train generator ###
  #######################
  noise = np.random.randn(batch_size, latent_dim)
  g_loss = combined_model_gen.train_on_batch(noise, ones)  
  #Now we are trying to fool the discriminator that generate imgs are real that's why we are providing label as 1
  # do it again!
  noise = np.random.randn(batch_size, latent_dim)
  g_loss = combined_model_gen.train_on_batch(noise, ones)
  # Save the losses
  d_losses.append(d_loss)  #save the loss at each epoch
  g_losses.append(g_loss)
  if epoch % 100 == 0:
    print(f"epoch: {epoch+1}/{epochs}, d_loss: {d_loss:.2f}, d_acc: {d_acc:.2f}, g_loss: {g_loss:.2f}")
  if epoch % sample_period == 0:
    sample_images(epoch)
# Out:
# epoch: 1/12000, d_loss: 0.61, d_acc: 0.53, g_loss: 0.38
# epoch: 101/12000, d_loss: 0.05, d_acc: 1.00, g_loss: 3.31
# epoch: 201/12000, d_loss: 0.48, d_acc: 0.69, g_loss: 1.81
# epoch: 301/12000, d_loss: 0.75, d_acc: 0.41, g_loss: 0.58
# epoch: 401/12000, d_loss: 0.69, d_acc: 0.50, g_loss: 0.62
# epoch: 501/12000, d_loss: 0.68, d_acc: 0.50, g_loss: 0.64
# epoch: 601/12000, d_loss: 0.68, d_acc: 0.47, g_loss: 0.64
# epoch: 701/12000, d_loss: 0.69, d_acc: 0.44, g_loss: 0.68
# epoch: 801/12000, d_loss: 0.67, d_acc: 0.55, g_loss: 0.68
# epoch: 901/12000, d_loss: 0.67, d_acc: 0.45, g_loss: 0.70
# epoch: 1001/12000, d_loss: 0.71, d_acc: 0.48, g_loss: 0.72
# epoch: 1101/12000, d_loss: 0.69, d_acc: 0.48, g_loss: 0.72
# epoch: 1201/12000, d_loss: 0.68, d_acc: 0.59, g_loss: 0.71
# epoch: 1301/12000, d_loss: 0.67, d_acc: 0.55, g_loss: 0.73
# epoch: 1401/12000, d_loss: 0.70, d_acc: 0.47, g_loss: 0.75
# epoch: 1501/12000, d_loss: 0.63, d_acc: 0.61, g_loss: 0.80
# epoch: 1601/12000, d_loss: 0.67, d_acc: 0.59, g_loss: 0.78
# epoch: 1701/12000, d_loss: 0.64, d_acc: 0.56, g_loss: 0.79
# epoch: 1801/12000, d_loss: 0.64, d_acc: 0.62, g_loss: 0.78
# epoch: 1901/12000, d_loss: 0.68, d_acc: 0.50, g_loss: 0.78
# epoch: 2001/12000, d_loss: 0.67, d_acc: 0.59, g_loss: 0.75
# epoch: 2101/12000, d_loss: 0.64, d_acc: 0.61, g_loss: 0.77
# epoch: 2201/12000, d_loss: 0.70, d_acc: 0.50, g_loss: 0.79
# epoch: 2301/12000, d_loss: 0.68, d_acc: 0.45, g_loss: 0.75
# epoch: 2401/12000, d_loss: 0.66, d_acc: 0.64, g_loss: 0.74
# epoch: 2501/12000, d_loss: 0.66, d_acc: 0.62, g_loss: 0.81
# epoch: 2601/12000, d_loss: 0.65, d_acc: 0.58, g_loss: 0.81
# epoch: 2701/12000, d_loss: 0.67, d_acc: 0.59, g_loss: 0.75
# epoch: 2801/12000, d_loss: 0.65, d_acc: 0.62, g_loss: 0.77
# epoch: 2901/12000, d_loss: 0.68, d_acc: 0.58, g_loss: 0.78
# epoch: 3001/12000, d_loss: 0.64, d_acc: 0.70, g_loss: 0.72
# epoch: 3101/12000, d_loss: 0.69, d_acc: 0.56, g_loss: 0.77
# epoch: 3201/12000, d_loss: 0.68, d_acc: 0.53, g_loss: 0.75
# epoch: 3301/12000, d_loss: 0.69, d_acc: 0.55, g_loss: 0.77
# epoch: 3401/12000, d_loss: 0.68, d_acc: 0.62, g_loss: 0.79
# epoch: 3501/12000, d_loss: 0.67, d_acc: 0.61, g_loss: 0.72
# epoch: 3601/12000, d_loss: 0.67, d_acc: 0.61, g_loss: 0.78
# epoch: 3701/12000, d_loss: 0.66, d_acc: 0.61, g_loss: 0.79
# epoch: 3801/12000, d_loss: 0.70, d_acc: 0.58, g_loss: 0.78
# epoch: 3901/12000, d_loss: 0.70, d_acc: 0.53, g_loss: 0.76
# epoch: 4001/12000, d_loss: 0.73, d_acc: 0.50, g_loss: 0.77
# epoch: 4101/12000, d_loss: 0.73, d_acc: 0.45, g_loss: 0.82
# epoch: 4201/12000, d_loss: 0.68, d_acc: 0.59, g_loss: 0.80
# epoch: 4301/12000, d_loss: 0.71, d_acc: 0.47, g_loss: 0.81
# epoch: 4401/12000, d_loss: 0.71, d_acc: 0.50, g_loss: 0.76
# epoch: 4501/12000, d_loss: 0.68, d_acc: 0.55, g_loss: 0.81
# epoch: 4601/12000, d_loss: 0.72, d_acc: 0.45, g_loss: 0.78
# epoch: 4701/12000, d_loss: 0.72, d_acc: 0.44, g_loss: 0.78
# epoch: 4801/12000, d_loss: 0.68, d_acc: 0.58, g_loss: 0.79
# epoch: 4901/12000, d_loss: 0.68, d_acc: 0.53, g_loss: 0.74
# epoch: 5001/12000, d_loss: 0.69, d_acc: 0.61, g_loss: 0.74
# epoch: 5101/12000, d_loss: 0.68, d_acc: 0.55, g_loss: 0.70
# epoch: 5201/12000, d_loss: 0.70, d_acc: 0.52, g_loss: 0.78
# epoch: 5301/12000, d_loss: 0.71, d_acc: 0.50, g_loss: 0.76
# epoch: 5401/12000, d_loss: 0.70, d_acc: 0.55, g_loss: 0.73
# epoch: 5501/12000, d_loss: 0.71, d_acc: 0.52, g_loss: 0.77
# epoch: 5601/12000, d_loss: 0.68, d_acc: 0.56, g_loss: 0.78
# epoch: 5701/12000, d_loss: 0.66, d_acc: 0.66, g_loss: 0.74
# epoch: 5801/12000, d_loss: 0.69, d_acc: 0.53, g_loss: 0.80
# epoch: 5901/12000, d_loss: 0.68, d_acc: 0.66, g_loss: 0.80
# epoch: 6001/12000, d_loss: 0.72, d_acc: 0.48, g_loss: 0.76
# epoch: 6101/12000, d_loss: 0.67, d_acc: 0.61, g_loss: 0.76
# epoch: 6201/12000, d_loss: 0.68, d_acc: 0.62, g_loss: 0.80
# epoch: 6301/12000, d_loss: 0.68, d_acc: 0.55, g_loss: 0.76
# epoch: 6401/12000, d_loss: 0.68, d_acc: 0.55, g_loss: 0.71
# epoch: 6501/12000, d_loss: 0.68, d_acc: 0.52, g_loss: 0.81
# epoch: 6601/12000, d_loss: 0.70, d_acc: 0.48, g_loss: 0.78
# epoch: 6701/12000, d_loss: 0.65, d_acc: 0.62, g_loss: 0.74
# epoch: 6801/12000, d_loss: 0.65, d_acc: 0.58, g_loss: 0.82
# epoch: 6901/12000, d_loss: 0.70, d_acc: 0.52, g_loss: 0.78
# epoch: 7001/12000, d_loss: 0.67, d_acc: 0.53, g_loss: 0.73
# epoch: 7101/12000, d_loss: 0.68, d_acc: 0.52, g_loss: 0.80
# epoch: 7201/12000, d_loss: 0.67, d_acc: 0.52, g_loss: 0.80
# epoch: 7301/12000, d_loss: 0.68, d_acc: 0.59, g_loss: 0.78
# epoch: 7401/12000, d_loss: 0.73, d_acc: 0.50, g_loss: 0.79
# epoch: 7501/12000, d_loss: 0.66, d_acc: 0.61, g_loss: 0.77
# epoch: 7601/12000, d_loss: 0.67, d_acc: 0.55, g_loss: 0.78
# epoch: 7701/12000, d_loss: 0.69, d_acc: 0.55, g_loss: 0.78
# epoch: 7801/12000, d_loss: 0.70, d_acc: 0.52, g_loss: 0.73
# epoch: 7901/12000, d_loss: 0.72, d_acc: 0.47, g_loss: 0.76
# epoch: 8001/12000, d_loss: 0.67, d_acc: 0.62, g_loss: 0.82
# epoch: 8101/12000, d_loss: 0.68, d_acc: 0.56, g_loss: 0.72
# epoch: 8201/12000, d_loss: 0.70, d_acc: 0.59, g_loss: 0.83
# epoch: 8301/12000, d_loss: 0.68, d_acc: 0.53, g_loss: 0.81
# epoch: 8401/12000, d_loss: 0.68, d_acc: 0.56, g_loss: 0.78
# epoch: 8501/12000, d_loss: 0.68, d_acc: 0.62, g_loss: 0.77
# epoch: 8601/12000, d_loss: 0.66, d_acc: 0.67, g_loss: 0.76
# epoch: 8701/12000, d_loss: 0.69, d_acc: 0.55, g_loss: 0.77
# epoch: 8801/12000, d_loss: 0.69, d_acc: 0.58, g_loss: 0.81
# epoch: 8901/12000, d_loss: 0.67, d_acc: 0.56, g_loss: 0.81
# epoch: 9001/12000, d_loss: 0.67, d_acc: 0.59, g_loss: 0.76
# epoch: 9101/12000, d_loss: 0.69, d_acc: 0.50, g_loss: 0.80
# epoch: 9201/12000, d_loss: 0.69, d_acc: 0.50, g_loss: 0.80
# epoch: 9301/12000, d_loss: 0.74, d_acc: 0.52, g_loss: 0.79
# epoch: 9401/12000, d_loss: 0.70, d_acc: 0.52, g_loss: 0.74
# epoch: 9501/12000, d_loss: 0.66, d_acc: 0.58, g_loss: 0.76
# epoch: 9601/12000, d_loss: 0.72, d_acc: 0.45, g_loss: 0.77
# epoch: 9701/12000, d_loss: 0.68, d_acc: 0.61, g_loss: 0.74
# epoch: 9801/12000, d_loss: 0.66, d_acc: 0.61, g_loss: 0.76
# epoch: 9901/12000, d_loss: 0.69, d_acc: 0.53, g_loss: 0.83
# epoch: 10001/12000, d_loss: 0.67, d_acc: 0.61, g_loss: 0.75
# epoch: 10101/12000, d_loss: 0.69, d_acc: 0.61, g_loss: 0.76
# epoch: 10201/12000, d_loss: 0.71, d_acc: 0.56, g_loss: 0.79
# epoch: 10301/12000, d_loss: 0.70, d_acc: 0.53, g_loss: 0.80
# epoch: 10401/12000, d_loss: 0.67, d_acc: 0.64, g_loss: 0.77
# epoch: 10501/12000, d_loss: 0.72, d_acc: 0.48, g_loss: 0.75
# epoch: 10601/12000, d_loss: 0.65, d_acc: 0.66, g_loss: 0.76
# epoch: 10701/12000, d_loss: 0.71, d_acc: 0.48, g_loss: 0.73
# epoch: 10801/12000, d_loss: 0.69, d_acc: 0.55, g_loss: 0.79
# epoch: 10901/12000, d_loss: 0.68, d_acc: 0.59, g_loss: 0.76
# epoch: 11001/12000, d_loss: 0.71, d_acc: 0.47, g_loss: 0.77
# epoch: 11101/12000, d_loss: 0.71, d_acc: 0.47, g_loss: 0.78
# epoch: 11201/12000, d_loss: 0.68, d_acc: 0.59, g_loss: 0.78
# epoch: 11301/12000, d_loss: 0.68, d_acc: 0.58, g_loss: 0.75
# epoch: 11401/12000, d_loss: 0.69, d_acc: 0.55, g_loss: 0.75
# epoch: 11501/12000, d_loss: 0.68, d_acc: 0.56, g_loss: 0.76
# epoch: 11601/12000, d_loss: 0.69, d_acc: 0.48, g_loss: 0.78
# epoch: 11701/12000, d_loss: 0.70, d_acc: 0.47, g_loss: 0.81
# epoch: 11801/12000, d_loss: 0.69, d_acc: 0.58, g_loss: 0.77
# epoch: 11901/12000, d_loss: 0.65, d_acc: 0.67, g_loss: 0.78

# %%
plt.plot(g_losses, label='g_losses')
plt.plot(d_losses, label='d_losses')
plt.legend()

# %%
from skimage.io import imread
a = imread('gan_images/0.png')
plt.imshow(a)

# %%
from skimage.io import imread
a = imread('gan_images/10000.png')
plt.imshow(a)
